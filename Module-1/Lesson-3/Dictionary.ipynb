# %% [markdown]
# # **Dictionary trong Python**

# %% [markdown]
# #Cách mở Mục Lục

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # I. Giới thiệu về Dictionary

# %% [markdown]
# **Kiểu dữ liệu Dictionary** là một tập hợp các cặp key-value không có thứ tự, có thể thay đổi và lập chỉ mục (truy cập phần tử theo chỉ mục).
#
# **Khởi tạo Dictionary** bằng dấu ngoặc nhọn ( {} ) và các phần tử là các cặp key-value sẽ nằm bên trong.
#
# **Mỗi cặp key-value** được xem như là một phần tử, mỗi phần tử cách nhau bởi dấu phẩy ( , )
#
# **Key và value** được phân biệt bởi một dấu hai chấm ( : ), trong đó key phải là duy nhất và value có thể là bất kỳ giá trị nào.

# %%
# Khởi tạo một dictionary theo cú pháp phổ biến:
# <name> = {<key_1: value_1>, <key_2: value_2>, ..., <key_n: value_n>}

dictCar = {
    "brand": "Honda",
    "model": "Honda Civic",
    "year": 1972
}
print(dictCar)
# Out:
# {'brand': 'Honda', 'model': 'Honda Civic', 'year': 1972}

# %% [markdown]
# # II. Thao tác với Dictionary

# %% [markdown]
# ## 1.Truy cập các item của Dictionary trong Python

# %% [markdown]
# Truy cập các item của Dictionary bằng cách sử dụng ***key*** của nó, bên ***trong dấu ngoặc vuông***, ví dụ:

# %%
singer = {
    'name' : 'Son Tung',
    'age' : 29,
    'song' : 'Chung ta cua tuong lai'
}
print(singer['name'])
# Out:
# Son Tung

# %% [markdown]
# Một cách khác là dùng hàm ***get()***, ví dụ:

# %%
print(singer.get('name'))
# Out:
# Son Tung

# %% [markdown]
# ## 2.Thay đổi giá trị của một Dictionary trong Python

# %% [markdown]
# Có thể ***thay đổi giá trị*** của một item cụ thể bằng khóa của nó (trong trường hợp khoá ***đã tồn tại***):
#
# (nếu không, một cặp key-value mới sẽ được tạo)

# %%
singer['song'] = 'Chung ta cua hien tai'

# %%
print(singer)
# Out:
# {'name': 'Son Tung', 'age': 29, 'song': 'Chung ta cua hien tai'}

# %% [markdown]
# ## 3.Duyệt các item của Dictionary trong Python

# %% [markdown]
# Có thể duyệt qua một Dictionary bằng cách sử dụng vòng lặp ***for***.
#
# Giá trị trả về sẽ là các key, khi đó có thể dùng hàm get() để lấy value của key tương ứng.

# %%
for x in singer: 
    print('Khóa trả về là:', x)
    print('Giá trị trả về là:', singer[x])
    print()
# Out:
# Khóa trả về là: name
# Giá trị trả về là: Son Tung
#
# Khóa trả về là: age
# Giá trị trả về là: 29
#
# Khóa trả về là: song
# Giá trị trả về là: Chung ta cua hien tai

# %% [markdown]
# Khi chỉ muốn lấy các value trong một Dictionary, có thể sử dụng hàm ***values()***, ví dụ:

# %%
print('Giá trị của Dictionary là:')
for value in singer.values(): 
    print(value)
# Out:
# Giá trị của Dictionary là:
# Son Tung
# 29
# Chung ta cua hien tai

# %% [markdown]
# Ngoài ra, còn các hàm tương tự như:
#
# ***keys()*** để chỉ lấy các key trong một Dictionary
#
# ***items()*** để lấy các cặp item trong một Dictionary

# %%
print('Khóa của Dictionary là: ')
for key in singer.keys(): 
    print(key)
# Out:
# Khóa của Dictionary là:
# name
# age
# song

# %%
print('Cặp giá trị của Dictionary là:')
for key, value in singer.items(): 
    print((key, value))
# Out:
# Cặp giá trị của Dictionary là:
# ('name', 'Son Tung')
# ('age', 29)
# ('song', 'Chung ta cua hien tai')

# %% [markdown]
# ## 4.Kiểm tra nếu key tồn tại

# %% [markdown]
# Để xác định xem một khóa (key) được chỉ định có ***tồn tại*** trong từ điển hay không, hãy sử dụng từ khóa ***in***:

# %%
if 'song' in singer: 
    print("Khóa 'song' có tồn tại!")
else: 
    print("Khóa 'song' không tồn tại!")
# Out:
# Khóa 'song' có tồn tại!

# %%
print("Khóa 'nam' có tồn tại!" if 'nam' in singer else "Khóa 'nam' không tồn tại!")
# Out:
# Khóa 'nam' không tồn tại!

# %% [markdown]
# ## 5.Độ dài của một Dictionary trong Python

# %% [markdown]
# Để xác định có bao nhiêu item (cặp key-value) trong Dictionary, hãy dùng hàm ***len()***.

# %%
print(len(singer))
# Out:
# 3

# %% [markdown]
# ## 6.Thêm các item vào Dictionary

# %% [markdown]
# ***Thêm một item*** vào Dictionary được thực hiện bằng cách ***sử dụng khóa mới và gán giá trị*** cho nó:

# %%
singer['Love'] = 'Yes'

# %%
print(singer)
# Out:
# {'name': 'Son Tung', 'age': 29, 'song': 'Chung ta cua hien tai', 'Love': 'Yes'}

# %% [markdown]
# ## 7.Xóa item của Dictionary

# %% [markdown]
# Có nhiều phương pháp để loại bỏ các item của một Dictionary.

# %% [markdown]
# ### Xóa item của Dictionary bằng hàm pop()
# Hàm ***pop()*** xóa item với key được ***chỉ định***:

# %%
singer.pop('Love')
# Out:
# 'Yes'

# %%
print(singer)
# Out:
# {'name': 'Son Tung', 'age': 29, 'song': 'Chung ta cua hien tai'}

# %% [markdown]
# ### Xóa item của Dictionary bằng hàm popitem()
# Hàm ***popitem()*** xóa item ***cuối cùng*** (trong các phiên bản trước 3.7, một mục ngẫu nhiên được xóa).

# %%
singer.popitem()
# Out:
# ('song', 'Chung ta cua hien tai')

# %%
singer
# Out:
# {'name': 'Son Tung', 'age': 29}

# %% [markdown]
# ### Xóa item của Dictionary bằng từ khóa del
# Lệnh ***del*** sẽ xóa item với key được ***chỉ định***:

# %%
del singer['age']

# %%
singer
# Out:
# {'name': 'Son Tung'}

# %% [markdown]
# ### Xóa item của Dictionary bằng hàm clear()
# Hàm ***clear()*** xóa ***toàn bộ*** các item của Dictionary.

# %%
singer.clear()

# %%
singer
# Out:
# {}

# %% [markdown]
# ## 8.Copy Dictionary trong Python

# %% [markdown]
# **Không thể sao chép từ điển chỉ bằng cách gán dict2 = dict1.**
#
# Vì dict2 sẽ chỉ là một tham chiếu đến dict1 và những thay đổi được thực hiện trên dict1 cũng sẽ xảy ra trên dict2.

# %% [markdown]
# Có nhiều cách để tạo một bản sao, một trong các cách đó là sử dụng hàm ***copy()***, ví dụ:

# %%
singer = {
    'name' : 'Son Tung',
    'age' : 29,
    'song' : 'Chung ta cua tuong lai'
}

singer2 = singer.copy()
singer2
# Out:
# {'name': 'Son Tung', 'age': 29, 'song': 'Chung ta cua tuong lai'}

# %% [markdown]
# Một cách khác để tạo một bản sao là khởi tạo một Dictionary mới dựa vào dictionary cũ.

# %%
singer2 = dict(singer)
singer2
# Out:
# {'name': 'Son Tung', 'age': 29, 'song': 'Chung ta cua tuong lai'}

# %%
singer2['name'] = 'MCK'
print(singer2)
singer
# Out:
# {'name': 'MCK', 'age': 29, 'song': 'Chung ta cua tuong lai'}
# {'name': 'Son Tung', 'age': 29, 'song': 'Chung ta cua tuong lai'}

# %%
singer['name'] = 'Den Vau'
singer2
# Out:
# {'name': 'MCK', 'age': 29, 'song': 'Chung ta cua tuong lai'}

# %% [markdown]
# ## 9.Dictionary lồng nhau trong Python

# %% [markdown]
# Một Dictionary cũng có thể chứa nhiều Dictionary khác, điều này được gọi là Dictionary lồng nhau, ví dụ:

# %%
cac_ca_si_lon = {
    'son tung' : {
        'tuoi' : 20, 
        'bai hat': 'Chung ta cua tuong lai'
    }, 
    'MCK' : {
        'tuoi' : 20, 
        'bai hat' : 'Chim Sau'
    }
}

cac_ca_si_lon
# Out:
# {'son tung': {'tuoi': 20, 'bai hat': 'Chung ta cua tuong lai'},
#  'MCK': {'tuoi': 20, 'bai hat': 'Chim Sau'}}

# %% [markdown]
# Với một khai báo khác rõ ràng, dể hiểu hơn, ví dụ trên tương đương với ví dụ sau:

# %%
son_tung = {
        'tuoi' : 20, 
        'bai hat': 'Chung ta cua tuong lai'
    }

MCK = {
    'tuoi' : 20, 
    'bai hat' : 'Chim Sau'
}

cac_ca_si_lon = {
    'son tung' : son_tung, 
    'MCK' : MCK
}

cac_ca_si_lon
# Out:
# {'son tung': {'tuoi': 20, 'bai hat': 'Chung ta cua tuong lai'},
#  'MCK': {'tuoi': 20, 'bai hat': 'Chim Sau'}}

# %% [markdown]
# ## 10.Constructor dict() trong Python

# %% [markdown]
# Cũng có thể sử dụng constructor dict() để tạo một Dictionary mới:

# %%
ca_si = dict(name = 'Son Tung', song = 'Chung ta cua tuong lai', age = 20)

# %%
ca_si
# Out:
# {'name': 'Son Tung', 'song': 'Chung ta cua tuong lai', 'age': 20}

# %% [markdown]
# ## 11.Các hàm và phương thức đã được xây dựng sẵn cho Dictionary trong Python

# %% [markdown]
# Python đã xây dựng sẵn các hàm sau để được sử dụng với Dictionary. Bạn có thể theo dõi ví dụ chi tiết về các hàm này ở phần dưới đây.

# %% [markdown]
# <table class="alt">
# <tbody>
# <tr>
# <th style="width:5%">STT</th>
# <th style="width:45%">Hàm</th>
# <th style="width:50%">Miêu tả</th>
# </tr>
# <tr>
# <td>1</td>
# <td>len(dict)</td>
# <td>Độ dài của dict. Nó sẽ là số item trong Dictionary này</td>
# </tr>
# <tr>
# <td>2</td>
# <td>str(dict)</td>
# <td>Tạo ra một biểu diễn chuỗi có thể in được của một dict</td>
# </tr>
# <tr>
# <td>3</td>
# <td>type(variable)</td>
# <td>Trả về kiểu của biến đã truyền. Nếu biến đã truyền là Dictionary, thì nó sẽ trả về một kiểu Dictionary</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# Các phương thức đã được xây dựng sẵn cho Dictionary trong Python:

# %% [markdown]
# <table class="alt">
# <tbody>
# <tr>
# <th style="width:5%">STT</th>
# <th style="width:45%">Hàm</th>
# <th style="width:50%">Miêu tả</th>
# </tr>
# <tr>
# <td>1</td>
# <td>dict.clear()</td>
# <td>Xóa tất cả phần tử của <i>dict</i></td>
# </tr>
# <tr>
# <td>2</td>
# <td>dict.copy()</td>
# <td>Trả về bản sao của <i>dict</i></td>
# </tr>
# <tr>
# <td>3</td>
# <td>fromkeys(seq,value1)/ fromkeys(seq)</td>
# <td>Được sử dụng để tạo một Dictionary mới từ dãy seq và value1. Trong đó dãy seq tạo nên các key và tất cả các key chia sẻ các giá trị từ value1. Trong trường hợp value1 không được cung cấp thì value của các key được thiết lập là None</td>
# </tr>
# <tr>
# <td>4</td>
# <td>dict.get(key, default=None)</td>
# <td>Trả về giá trị của key đã cho. Nếu key không có mặt thì phương thức này trả về None</td>
# </tr>
# <tr>
# <td>5</td>
# <td>dict.has-key(key)</td>
# <td>Trả về true nếu key là có mặt trong Dictionary, nếu không là false</td>
# </tr>
# <tr>
# <td>6</td>
# <td>dict.items()</td>
# <td>Trả về tất cả các cặp (key-value) của một Dictionary</td>
# </tr>
# <tr>
# <td>7</td>
# <td>dict.keys()</td>
# <td>Trả về tất cả các key của một Dictionary</td>
# </tr>
# <tr>
# <td>8</td>
# <td>dict.setdefault(key, default=None)</td>
# <td>Tương tự get(), nhưng sẽ thiết lập dict[key]=default nếu <i>key</i> là không tồn tại trong dict</td>
# </tr>
# <tr>
# <td>9</td>
# <td>dict.update(dict2)</td>
# <td>Được sử dụng để thêm các item của dictionary 2 vào Dictionary đầu tiên</td>
# </tr>
# <tr>
# <td>10</td>
# <td>dict.values()</td>
# <td>Trả về tất cả các value của một Dictionary</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# # III. Bài tập về Dictionary
#
# ### Sau một thời gian cần cù livestream bán hàng online bạn đã giàu và đủ tiền mở khách sạn. Bạn cần quản lý danh sách các phòng và trạng thái đặt phòng (đã đặt-booked hoặc chưa đặt-available).

# %% [markdown]
# ## 1.Bài tập 1:
# Tạo một dictionary chứa thông tin về các phòng trong khách sạn, ví dụ: {"101": "available", "102": "booked", "103": "available"}.

# %% [markdown]
# ### Answer

# %%
khach_san = {'101': 'Available', '102': 'Booked', '103': 'Available', '104': 'Booked'}
khach_san
# Out:
# {'101': 'Available', '102': 'Booked', '103': 'Available', '104': 'Booked'}

# %% [markdown]
# ## 2.Bài tập 2:
#
# Thêm một phòng mới vào danh sách và đặt trạng thái của nó là "available".
#
# Đặt một phòng có sẵn thành trạng thái "booked".

# %% [markdown]
# ### Answer

# %%
khach_san['105'] = 'Available'
khach_san['101'] = 'Booked'
khach_san
# Out:
# {'101': 'Booked',
#  '102': 'Booked',
#  '103': 'Available',
#  '104': 'Booked',
#  '105': 'Available'}

# %% [markdown]
# ## 3.Bài tập 3:
# Xóa một phòng khỏi danh sách.
#
# In ra danh sách các phòng và trạng thái của chúng.

# %% [markdown]
# ### Answer

# %%
khach_san.pop('101')
# Out:
# 'Booked'

# %%
print('Danh sách phòng và trạng thái:')
for x in khach_san:
    print(f'Phòng: {x}, trạng thái: {khach_san[x]}')
# Out:
# Danh sách phòng và trạng thái:
# Phòng: 102, trạng thái: Booked
# Phòng: 103, trạng thái: Available
# Phòng: 104, trạng thái: Booked
# Phòng: 105, trạng thái: Available
